# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext autotime
# %config InlineBackend.figure_format = 'retina'

import itertools
import os
from collections import defaultdict
from pathlib import Path
from sklearn.model_selection import KFold
from toolz import valmap
from typing import Tuple

for folder in itertools.chain([Path.cwd()], Path.cwd().parents):
    if (folder / 'Pipfile').exists():
        os.chdir(folder)
        break

from functional import try_except
from utils import Timer

from IPython.core.display import clear_output
from cache import save_data, load_data
from evaluation_functions import  cross_validate_model_sets, \
    compute_classification_metrics_from_result
from notebooks.heart_transplant.dependencies.heart_transplant_functions import  get_rolling_cv
from notebooks.heart_transplant.dependencies.heart_transplant_pipelines import   get_xgboost_pipeline
from matplotlib import pyplot as plt
from notebooks.heart_transplant.dependencies.heart_transplant_data import get_rolling_cv_inputs_cached
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 28 ms (started: 2021-03-25 11:28:53 +00:00)

# %%
_, y, X, dataset_raw, sampling_sets = get_rolling_cv_inputs_cached()
# Out:
# [Memory]997.9s, 16.6min : Loading get_rolling_cv_inputs...
# time: 1.67 s (started: 2021-03-25 11:44:20 +00:00)

# %%
RESULTS_IDENTIFIER = 'heart_transplant_step_wise_feature_selection_results_optimized'
FEATURES_IDENTIFIER = 'heart_transplant_step_wise_feature_selection_used_features_optimized'

all_potential_features = list(X.columns)
# Out:
# time: 3.19 ms (started: 2021-03-25 11:44:24 +00:00)

# %%
try:
    final_results = load_data(RESULTS_IDENTIFIER)
except FileNotFoundError:
    final_results = defaultdict(partial(defaultdict, partial(defaultdict)))

try:
    final_used_features = load_data(FEATURES_IDENTIFIER)
except FileNotFoundError:
    final_used_features = defaultdict(partial(defaultdict))
# Out:
# time: 3.91 ms (started: 2021-03-25 11:44:26 +00:00)

# %%
def roc_for_feature(result_for_feature):
    return pipe(
       result_for_feature,
       partial(compute_classification_metrics_from_result,
            y,
            target_variable='y_scores',
            threshold=0.5
       ),
       partial(map, lambda i2: i2['roc_auc']),
       list,
       np.mean
    )

def get_max_roc_auc_from_results(results) -> Tuple[str, float]:
    return pipe(
        results,
        partial(valmap, roc_for_feature),
        dict.items,
        partial(max, key=lambda i: i[1])
    )
# Out:
# time: 1.08 ms (started: 2021-03-25 11:44:28 +00:00)

# %%
for method, pipeline in [('xgboost', partial(get_xgboost_pipeline, n_jobs=10))]:
    print(f'- {method}')
    resumed_iteration = len(final_used_features[method])
    if resumed_iteration > 0:
        used_features = final_used_features[method][resumed_iteration - 1]
        print(f'Resuming iteration {resumed_iteration}; Selected features so far: {used_features}' )
    else:
        used_features = []

    potential_features = set(all_potential_features)-set(used_features)

    for iteration in range(resumed_iteration, len(all_potential_features)):
        print('iter', iteration, 'available', len(potential_features))
        timer = Timer()
        current_metrics_per_feature =  {}
        for feature in potential_features.copy():

            if f'log_{feature}' in X.columns:
                feature = f'log_{feature}'

            print(f'{feature}')
            try:
                X_selected = X[list(set(used_features) | { feature })]

                result = cross_validate_model_sets(
                    # Optimized hyperparameters
                    classifier=pipeline(X=X_selected, y=y).set_params(**{
                        'classifier__colsample_bytree': 0.5080817028881132,
                        'classifier__gamma': 3.092864665001854,
                        'classifier__learning_rate': 0.08951636759116892,
                        'classifier__max_depth': 2,
                        'classifier__min_child_weight': 4.0,
                        'classifier__n_estimators': 140,
                        'classifier__subsample': 0.7437975255362691
                    }),
                    X=X_selected,
                    y=y,
                    sets=sampl,
                    return_model=False,
                    parallel=False,
                )

                print('ROC AUC', roc_for_feature(result))
                print('Selected features', ','.join(X_selected.columns))
                print()
                final_results[method][iteration][feature] = result

            except Exception as e:
                print(f'Skipping {feature}')
                print('Exception', e)

        selected_feature, selected_roc_auc = get_max_roc_auc_from_results(final_results[method][iteration])

        potential_features.remove(selected_feature)
        used_features.append(selected_feature)
        final_used_features[method][iteration] = used_features.copy()

        save_data(RESULTS_IDENTIFIER, final_results)
        save_data(FEATURES_IDENTIFIER, final_used_features)
        print()
        print('---------------------')
        print(f'Selected feature: {selected_feature}')
        print('ROC AUC', selected_roc_auc)
        print(f'All features:', used_features)
        print(timer)
        print('---------------------')
        print()
# Out:
# - xgboost
# iter 0 available 114
# log_tbili_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.511974987067541
# Selected features log_tbili_don
#
# log_age
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5478566675385739
# Selected features log_age
#
# impl_defibril
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5055078422995338
# Selected features impl_defibril
#
# cancer_site_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.501870804205964
# Selected features cancer_site_don
#
# prior_card_surg_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5303955823860673
# Selected features prior_card_surg_trr
#
# coronary_angio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5258407817458473
# Selected features coronary_angio
#
# tah ever
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.5
# Selected features tah ever
#
# tattoos
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5122905194732666
# Selected features tattoos
#
# biopsy_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4997917656954215
# Selected features biopsy_dgn
#
# log_wgt_kg_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5119688127306788
# Selected features log_wgt_kg_don_calc
#
# gender_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5169182516504102
# Selected features gender_don
#
# cmv_igm
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4956670066676585
# Selected features cmv_igm
#
# other_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4975202434382761
# Selected features other_inf_don
#
# retransplant
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5146777190240324
# Selected features retransplant
#
# hbv_sur_antigen_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49982136416411177
# Selected features hbv_sur_antigen_don
#
# diab
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.48871784129357543
# Selected features diab
#
# hist_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5035142592188396
# Selected features hist_cancer_don
#
# log_age_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5532694365949629
# Selected features log_age_don
#
# prev_tx_any
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5147549569706397
# Selected features prev_tx_any
#
# hist_cig_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.506346425488689
# Selected features hist_cig_don
#
# lv_eject_meth
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4989796919619423
# Selected features lv_eject_meth
#
# dial_prior_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5296986710465021
# Selected features dial_prior_tx
#
# hemo_co_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5088299369533676
# Selected features hemo_co_tcr
#
# vessels_50sten
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5001292097478396
# Selected features vessels_50sten
#
# hbv_core_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5018218332978187
# Selected features hbv_core_don
#
# hep_c_anti_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.501020172173484
# Selected features hep_c_anti_don
#
# log_cmassratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5217489756530779
# Selected features log_cmassratio
#
# log_bun_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4966971878891623
# Selected features log_bun_don
#
# life_sup_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5214646065783312
# Selected features life_sup_trr
#
# ecd_donor
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5099262953336916
# Selected features ecd_donor
#
# cmv_igg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5120561431110765
# Selected features cmv_igg
#
# prior_card_surg_type_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4951027507400241
# Selected features prior_card_surg_type_tcr
#
# prev_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5131395372489334
# Selected features prev_tx
#
# med_cond_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5388129856322577
# Selected features med_cond_trr
#
# bmi_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49927385423302084
# Selected features bmi_don_calc
#
# log_creat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5008212915256945
# Selected features log_creat_don
#
# log_sgpt_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5085362791251139
# Selected features log_sgpt_don
#
# vasodil_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4999220242086296
# Selected features vasodil_don
#
# hemo_pa_mn_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5156450977665993
# Selected features hemo_pa_mn_tcr
#
# hiv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49992302853434717
# Selected features hiv_serostatus
#
# congenital
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5208856705052487
# Selected features congenital
#
# log_tbili
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5681093223982384
# Selected features log_tbili
#
# contin_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5167191000276333
# Selected features contin_oth_drug_don
#
# hist_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5194927036644292
# Selected features hist_oth_drug_don
#
# sexmatch
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5150277418272763
# Selected features sexmatch
#
# vent_support_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5332008126529324
# Selected features vent_support_after_list
#
# ecmo_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.517399723650776
# Selected features ecmo_trr
#
# log_creat_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5767768706158688
# Selected features log_creat_trr
#
# hemo_sys_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5309043291304628
# Selected features hemo_sys_tcr
#
# log_hgt_cm_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.511029930891133
# Selected features log_hgt_cm_don_calc
#
# hemo_pa_dia_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5124560461081215
# Selected features hemo_pa_dia_tcr
#
# abo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5089390836747094
# Selected features abo
#
# blood_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4949912558477046
# Selected features blood_inf_don
#
# hist_alcohol_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.502029468714083
# Selected features hist_alcohol_old_don
#
# anyecmo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5190984171463754
# Selected features anyecmo
#
# donor insulin
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.49885553853230363
# Selected features donor insulin
#
# thoracic_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5545395308692647
# Selected features thoracic_dgn
#
# cereb_vasc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5022608095807832
# Selected features cereb_vasc
#
# extracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49972467364686374
# Selected features extracranial_cancer_don
#
# cmv_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5092320429218002
# Selected features cmv_don
#
# alcohol_heavy_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py:745: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# ROC AUC 0.4982557861257153
# Selected features alcohol_heavy_don
#
# log_most_rcnt_creat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5536029127864163
# Selected features log_most_rcnt_creat
#
# death_mech_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5300806553682477
# Selected features death_mech_don
#
# ethcat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4938664032047868
# Selected features ethcat_don
#
# multiorg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5032807520429519
# Selected features multiorg
#
# abo_mat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5060790510819724
# Selected features abo_mat
#
# urine_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4972776251011579
# Selected features urine_inf_don
#
# gender
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5050977371275662
# Selected features gender
#
# hematocrit_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5012659132790989
# Selected features hematocrit_don
#
# tot_serum_album
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5279947064062179
# Selected features tot_serum_album
#
# education
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5128444761058304
# Selected features education
#
# protein_urine
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4960137678985999
# Selected features protein_urine
#
# skin_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49976986331104034
# Selected features skin_cancer_don
#
# hemo_pcw_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.521435101505234
# Selected features hemo_pcw_tcr
#
# height ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.510995907950463
# Selected features height ratio
#
# pulm_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49553366889455686
# Selected features pulm_inf_don
#
# func_stat_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5405008559470386
# Selected features func_stat_tcr
#
# log_hgt_cm_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5297237500018475
# Selected features log_hgt_cm_calc
#
# vdrl_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5006300639976616
# Selected features vdrl_don
#
# hcv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5023127912601557
# Selected features hcv_serostatus
#
# hist_mi
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49966715505863957
# Selected features hist_mi
#
# ebv_igg_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py:745: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# .
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py:745: RuntimeWarning: invalid value encountered in true_divide
#   return all_features / all_features.sum()
# ROC AUC 0.5077989748430127
# Selected features ebv_igg_cad_don
#
# pvr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5163391930697571
# Selected features pvr
#
# ebv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4972316397522444
# Selected features ebv_serostatus
#
# log_newpra
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5223526055721963
# Selected features log_newpra
#
# transfusions
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5511288980981959
# Selected features transfusions
#
# ethcat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5069795246489714
# Selected features ethcat
#
# hbv_sur_antigen
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49930789030981093
# Selected features hbv_sur_antigen
#
# clin_infect_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4981807675807023
# Selected features clin_infect_don
#
# cod_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5225967105724586
# Selected features cod_cad_don
#
# log_wgt_kg_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5205661670458382
# Selected features log_wgt_kg_calc
#
# anyvent
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5332008126529324
# Selected features anyvent
#
# log_ischtime
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5379697820968764
# Selected features log_ischtime
#
# lv_eject
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5052727782686994
# Selected features lv_eject
#
# malig
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5034735707468946
# Selected features malig
#
# hist_hypertens_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.511262110068369
# Selected features hist_hypertens_don
#
# diabetes_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4987851734201251
# Selected features diabetes_don
#
# iabp_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5012732360976664
# Selected features iabp_tcr
#
# weight ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5014268070049809
# Selected features weight ratio
#
# hist_cocaine_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5052060609178461
# Selected features hist_cocaine_don
#
# diag
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5575720371266619
# Selected features diag
#
# inotropes_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.4950722831302635
# Selected features inotropes_tcr
#
# hist_iv_drug_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.5000785211109615
# Selected features hist_iv_drug_old_don
#
# log_sgot_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5011746810560649
# Selected features log_sgot_don
#
# bmi_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5101334919236663
# Selected features bmi_calc
#
# hbv_core
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5010501346527113
# Selected features hbv_core
#
# cig_use
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.49581230992792985
# Selected features cig_use
#
# ventilator_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5166081693270512
# Selected features ventilator_tcr
#
# cmv_status
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5146326381591609
# Selected features cmv_status
#
# intracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ROC AUC 0.4999121426754253
# Selected features intracranial_cancer_don
#
# log_distance
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.50628649368982
# Selected features log_distance
#
# dial_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5256913779252333
# Selected features dial_after_list
#
# abo_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5125582802156832
# Selected features abo_don
#
# prior_card_surg_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5479302968910701
# Selected features prior_card_surg_tcr
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sitnarf/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------
# Selected feature: log_creat_trr
# ROC AUC 0.5767768706158688
# All features: ['log_creat_trr']
# Time elapsed: 0:08:46
# ---------------------
#
# iter 1 available 113
# log_tbili_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5780831140107239
# Selected features log_tbili_don,log_creat_trr
#
# log_age
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5939631623735339
# Selected features log_creat_trr,log_age
#
# impl_defibril
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5784136125103819
# Selected features impl_defibril,log_creat_trr
#
# cancer_site_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5788782206243238
# Selected features cancer_site_don,log_creat_trr
#
# prior_card_surg_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5822754020912033
# Selected features log_creat_trr,prior_card_surg_trr
#
# coronary_angio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5843698246283865
# Selected features log_creat_trr,coronary_angio
#
# tah ever
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5775479920770713
# Selected features log_creat_trr,tah ever
#
# tattoos
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5777803528832229
# Selected features tattoos,log_creat_trr
#
# biopsy_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5770303737864688
# Selected features biopsy_dgn,log_creat_trr
#
# log_wgt_kg_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5855808788802069
# Selected features log_wgt_kg_don_calc,log_creat_trr
#
# gender_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5839427995020748
# Selected features log_creat_trr,gender_don
#
# cmv_igm
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5726632941037292
# Selected features log_creat_trr,cmv_igm
#
# other_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5754811544101929
# Selected features log_creat_trr,other_inf_don
#
# retransplant
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5839536564765846
# Selected features retransplant,log_creat_trr
#
# hbv_sur_antigen_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5771211978016485
# Selected features hbv_sur_antigen_don,log_creat_trr
#
# diab
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5745430953377106
# Selected features log_creat_trr,diab
#
# hist_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5803741987350839
# Selected features log_creat_trr,hist_cancer_don
#
# log_age_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6004726567142534
# Selected features log_age_don,log_creat_trr
#
# prev_tx_any
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5818565136634131
# Selected features log_creat_trr,prev_tx_any
#
# hist_cig_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5768339722548037
# Selected features log_creat_trr,hist_cig_don
#
# lv_eject_meth
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5770264712188733
# Selected features log_creat_trr,lv_eject_meth
#
# dial_prior_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5879696312932654
# Selected features log_creat_trr,dial_prior_tx
#
# hemo_co_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5779096765038018
# Selected features log_creat_trr,hemo_co_tcr
#
# vessels_50sten
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5773189327544999
# Selected features vessels_50sten,log_creat_trr
#
# hbv_core_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5774623679974713
# Selected features hbv_core_don,log_creat_trr
#
# hep_c_anti_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5774700987214669
# Selected features hep_c_anti_don,log_creat_trr
#
# log_cmassratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5851290203903614
# Selected features log_cmassratio,log_creat_trr
#
# log_bun_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5736459044012321
# Selected features log_creat_trr,log_bun_don
#
# life_sup_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5814161872992634
# Selected features life_sup_trr,log_creat_trr
#
# ecd_donor
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5828675779163526
# Selected features ecd_donor,log_creat_trr
#
# cmv_igg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5765887609371497
# Selected features cmv_igg,log_creat_trr
#
# prior_card_surg_type_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5801475947888446
# Selected features log_creat_trr,prior_card_surg_type_tcr
#
# prev_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5816009149773346
# Selected features prev_tx,log_creat_trr
#
# med_cond_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5904517343909629
# Selected features med_cond_trr,log_creat_trr
#
# bmi_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5753414845185022
# Selected features bmi_don_calc,log_creat_trr
#
# log_creat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5759024374284336
# Selected features log_creat_trr,log_creat_don
#
# log_sgpt_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5762626200436117
# Selected features log_creat_trr,log_sgpt_don
#
# vasodil_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5764218816720099
# Selected features log_creat_trr,vasodil_don
#
# hemo_pa_mn_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5765854416335091
# Selected features hemo_pa_mn_tcr,log_creat_trr
#
# hiv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5774385183785559
# Selected features hiv_serostatus,log_creat_trr
#
# congenital
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5964983362591433
# Selected features log_creat_trr,congenital
#
# log_tbili
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6051896929174176
# Selected features log_creat_trr,log_tbili
#
# contin_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5822180507718955
# Selected features log_creat_trr,contin_oth_drug_don
#
# hist_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5828070962996127
# Selected features hist_oth_drug_don,log_creat_trr
#
# sexmatch
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5831904787994678
# Selected features sexmatch,log_creat_trr
#
# vent_support_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.589521111539524
# Selected features vent_support_after_list,log_creat_trr
#
# ecmo_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5921119275831453
# Selected features ecmo_trr,log_creat_trr
#
# hemo_sys_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5868990336741708
# Selected features log_creat_trr,hemo_sys_tcr
#
# log_hgt_cm_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5855920451966395
# Selected features log_creat_trr,log_hgt_cm_don_calc
#
# hemo_pa_dia_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5783074591825567
# Selected features hemo_pa_dia_tcr,log_creat_trr
#
# abo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5784434070499925
# Selected features log_creat_trr,abo
#
# blood_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5775097889319019
# Selected features log_creat_trr,blood_inf_don
#
# hist_alcohol_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.577323890666763
# Selected features hist_alcohol_old_don,log_creat_trr
#
# anyecmo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5933563135958432
# Selected features anyecmo,log_creat_trr
#
# donor insulin
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5767705196192405
# Selected features donor insulin,log_creat_trr
#
# thoracic_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6041010869947371
# Selected features thoracic_dgn,log_creat_trr
#
# cereb_vasc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5765742404127763
# Selected features cereb_vasc,log_creat_trr
#
# extracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5768385205340041
# Selected features log_creat_trr,extracranial_cancer_don
#
# cmv_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5767393672485569
# Selected features log_creat_trr,cmv_don
#
# alcohol_heavy_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5756091392521954
# Selected features alcohol_heavy_don,log_creat_trr
#
# log_most_rcnt_creat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5804777441823711
# Selected features log_most_rcnt_creat,log_creat_trr
#
# death_mech_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5876510012596481
# Selected features log_creat_trr,death_mech_don
#
# ethcat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5744188753454472
# Selected features ethcat_don,log_creat_trr
#
# multiorg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5758807776071007
# Selected features log_creat_trr,multiorg
#
# abo_mat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5792647885262668
# Selected features abo_mat,log_creat_trr
#
# urine_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5765110903803161
# Selected features urine_inf_don,log_creat_trr
#
# gender
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.582884173421564
# Selected features gender,log_creat_trr
#
# hematocrit_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5653502012193585
# Selected features log_creat_trr,hematocrit_don
#
# tot_serum_album
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5824733156909908
# Selected features log_creat_trr,tot_serum_album
#
# education
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5807187467677934
# Selected features log_creat_trr,education
#
# protein_urine
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5754526172439689
# Selected features protein_urine,log_creat_trr
#
# skin_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.576571241413532
# Selected features skin_cancer_don,log_creat_trr
#
# hemo_pcw_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5830937694946396
# Selected features log_creat_trr,hemo_pcw_tcr
#
# height ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5794792062126108
# Selected features height ratio,log_creat_trr
#
# pulm_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5755111576107718
# Selected features log_creat_trr,pulm_inf_don
#
# func_stat_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5852519407522123
# Selected features log_creat_trr,func_stat_tcr
#
# log_hgt_cm_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.596307675589109
# Selected features log_creat_trr,log_hgt_cm_calc
#
# vdrl_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.576670499613696
# Selected features vdrl_don,log_creat_trr
#
# hcv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5761657724600495
# Selected features hcv_serostatus,log_creat_trr
#
# hist_mi
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5768433154255143
# Selected features hist_mi,log_creat_trr
#
# ebv_igg_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5764849973105546
# Selected features ebv_igg_cad_don,log_creat_trr
#
# pvr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5813353002720488
# Selected features pvr,log_creat_trr
#
# ebv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5759809728644817
# Selected features log_creat_trr,ebv_serostatus
#
# log_newpra
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5858904887034109
# Selected features log_creat_trr,log_newpra
#
# transfusions
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5989437871712224
# Selected features transfusions,log_creat_trr
#
# ethcat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5775341825822848
# Selected features ethcat,log_creat_trr
#
# hbv_sur_antigen
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5762108441679976
# Selected features hbv_sur_antigen,log_creat_trr
#
# clin_infect_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5744335465536085
# Selected features clin_infect_don,log_creat_trr
#
# cod_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5881959064166327
# Selected features log_creat_trr,cod_cad_don
#
# log_wgt_kg_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5873029663539039
# Selected features log_wgt_kg_calc,log_creat_trr
#
# anyvent
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5903495397380895
# Selected features anyvent,log_creat_trr
#
# log_ischtime
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.593766233541418
# Selected features log_creat_trr,log_ischtime
#
# lv_eject
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.573775532322565
# Selected features lv_eject,log_creat_trr
#
# malig
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5783730368626597
# Selected features malig,log_creat_trr
#
# hist_hypertens_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.578530357788623
# Selected features hist_hypertens_don,log_creat_trr
#
# diabetes_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5773530881355149
# Selected features diabetes_don,log_creat_trr
#
# iabp_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5754889650134705
# Selected features log_creat_trr,iabp_tcr
#
# weight ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.572121678224229
# Selected features log_creat_trr,weight ratio
#
# hist_cocaine_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5777614081849192
# Selected features log_creat_trr,hist_cocaine_don
#
# diag
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.605978625923104
# Selected features diag,log_creat_trr
#
# inotropes_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5744202133709737
# Selected features inotropes_tcr,log_creat_trr
#
# hist_iv_drug_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5767698272496309
# Selected features hist_iv_drug_old_don,log_creat_trr
#
# log_sgot_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5746836913838319
# Selected features log_sgot_don,log_creat_trr
#
# bmi_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5746667318619758
# Selected features bmi_calc,log_creat_trr
#
# hbv_core
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5760889067419732
# Selected features hbv_core,log_creat_trr
#
# cig_use
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.56421451412573
# Selected features cig_use,log_creat_trr
#
# ventilator_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5867593180216483
# Selected features ventilator_tcr,log_creat_trr
#
# cmv_status
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.576588712972674
# Selected features log_creat_trr,cmv_status
#
# intracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5774076608739587
# Selected features log_creat_trr,intracranial_cancer_don
#
# log_distance
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5739608372739238
# Selected features log_creat_trr,log_distance
#
# dial_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5857854154480358
# Selected features dial_after_list,log_creat_trr
#
# abo_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5779756386413436
# Selected features abo_don,log_creat_trr
#
# prior_card_surg_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5900716990842576
# Selected features prior_card_surg_tcr,log_creat_trr
#
#
# ---------------------
# Selected feature: diag
# ROC AUC 0.605978625923104
# All features: ['log_creat_trr', 'diag']
# Time elapsed: 0:09:00
# ---------------------
#
# iter 2 available 112
# log_tbili_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.607599967411902
# Selected features log_tbili_don,diag,log_creat_trr
#
# log_age
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6151121250749504
# Selected features diag,log_creat_trr,log_age
#
# impl_defibril
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6051746914418072
# Selected features impl_defibril,diag,log_creat_trr
#
# cancer_site_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6091162793551218
# Selected features diag,cancer_site_don,log_creat_trr
#
# prior_card_surg_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6111910256807227
# Selected features diag,log_creat_trr,prior_card_surg_trr
#
# coronary_angio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6152068585019249
# Selected features diag,log_creat_trr,coronary_angio
#
# tah ever
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.607202154726475
# Selected features diag,log_creat_trr,tah ever
#
# tattoos
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6065944260010705
# Selected features tattoos,diag,log_creat_trr
#
# biopsy_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073968474189777
# Selected features biopsy_dgn,diag,log_creat_trr
#
# log_wgt_kg_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6081625302058915
# Selected features log_wgt_kg_don_calc,diag,log_creat_trr
#
# gender_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6108035961457824
# Selected features diag,log_creat_trr,gender_don
#
# cmv_igm
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6039673221901724
# Selected features diag,log_creat_trr,cmv_igm
#
# other_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6069396646424808
# Selected features diag,log_creat_trr,other_inf_don
#
# retransplant
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6068817100199986
# Selected features diag,log_creat_trr,retransplant
#
# hbv_sur_antigen_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6070716480171778
# Selected features diag,hbv_sur_antigen_don,log_creat_trr
#
# diab
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.603081321697183
# Selected features diag,log_creat_trr,diab
#
# hist_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6093569932211579
# Selected features diag,log_creat_trr,hist_cancer_don
#
# log_age_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6213144314138055
# Selected features log_age_don,diag,log_creat_trr
#
# prev_tx_any
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6075472592142903
# Selected features diag,log_creat_trr,prev_tx_any
#
# hist_cig_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6078726025710253
# Selected features diag,log_creat_trr,hist_cig_don
#
# lv_eject_meth
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6074332859541278
# Selected features diag,log_creat_trr,lv_eject_meth
#
# dial_prior_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6138042501673714
# Selected features diag,log_creat_trr,dial_prior_tx
#
# hemo_co_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.603228110727587
# Selected features diag,log_creat_trr,hemo_co_tcr
#
# vessels_50sten
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6077751165055989
# Selected features vessels_50sten,diag,log_creat_trr
#
# hbv_core_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073908295436569
# Selected features diag,hbv_core_don,log_creat_trr
#
# hep_c_anti_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6077032817457856
# Selected features diag,hep_c_anti_don,log_creat_trr
#
# log_cmassratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.607890790495738
# Selected features diag,log_cmassratio,log_creat_trr
#
# log_bun_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6052946506219563
# Selected features diag,log_creat_trr,log_bun_don
#
# life_sup_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6116808463678828
# Selected features life_sup_trr,diag,log_creat_trr
#
# ecd_donor
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6125744563300423
# Selected features diag,log_creat_trr,ecd_donor
#
# cmv_igg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.606682441195182
# Selected features diag,cmv_igg,log_creat_trr
#
# prior_card_surg_type_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6044272485781431
# Selected features diag,log_creat_trr,prior_card_surg_type_tcr
#
# prev_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6080746991838054
# Selected features diag,prev_tx,log_creat_trr
#
# med_cond_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6119160767489441
# Selected features med_cond_trr,diag,log_creat_trr
#
# bmi_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6042069569294355
# Selected features diag,bmi_don_calc,log_creat_trr
#
# log_creat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6025594527666512
# Selected features diag,log_creat_trr,log_creat_don
#
# log_sgpt_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6041208205685364
# Selected features diag,log_creat_trr,log_sgpt_don
#
# vasodil_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6067189878407873
# Selected features diag,log_creat_trr,vasodil_don
#
# hemo_pa_mn_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6049953761691081
# Selected features diag,log_creat_trr,hemo_pa_mn_tcr
#
# hiv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6068507063769705
# Selected features diag,hiv_serostatus,log_creat_trr
#
# congenital
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6089705924625692
# Selected features diag,log_creat_trr,congenital
#
# log_tbili
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.625628925038315
# Selected features diag,log_creat_trr,log_tbili
#
# contin_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6093205002160995
# Selected features diag,log_creat_trr,contin_oth_drug_don
#
# hist_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6095883970568395
# Selected features hist_oth_drug_don,diag,log_creat_trr
#
# sexmatch
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6108176817429312
# Selected features sexmatch,diag,log_creat_trr
#
# vent_support_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6105414540527586
# Selected features vent_support_after_list,diag,log_creat_trr
#
# ecmo_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6142619335709847
# Selected features ecmo_trr,diag,log_creat_trr
#
# hemo_sys_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.608511413138141
# Selected features diag,log_creat_trr,hemo_sys_tcr
#
# log_hgt_cm_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6081487217383756
# Selected features diag,log_creat_trr,log_hgt_cm_don_calc
#
# hemo_pa_dia_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6040155463752026
# Selected features diag,log_creat_trr,hemo_pa_dia_tcr
#
# abo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6083645003867604
# Selected features diag,log_creat_trr,abo
#
# blood_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6071986001188239
# Selected features diag,log_creat_trr,blood_inf_don
#
# hist_alcohol_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6075347073153525
# Selected features hist_alcohol_old_don,diag,log_creat_trr
#
# anyecmo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6145727621501021
# Selected features anyecmo,diag,log_creat_trr
#
# donor insulin
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6070466532207232
# Selected features diag,log_creat_trr,donor insulin
#
# thoracic_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6087721207882649
# Selected features diag,thoracic_dgn,log_creat_trr
#
# cereb_vasc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.607690860113675
# Selected features cereb_vasc,diag,log_creat_trr
#
# extracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073367031289847
# Selected features diag,log_creat_trr,extracranial_cancer_don
#
# cmv_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073480023848189
# Selected features diag,log_creat_trr,cmv_don
#
# alcohol_heavy_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6049307905181671
# Selected features alcohol_heavy_don,diag,log_creat_trr
#
# log_most_rcnt_creat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6074075355979246
# Selected features diag,log_creat_trr,log_most_rcnt_creat
#
# death_mech_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6130900920478729
# Selected features diag,log_creat_trr,death_mech_don
#
# ethcat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6056926656904623
# Selected features ethcat_don,diag,log_creat_trr
#
# multiorg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6068216057936585
# Selected features diag,log_creat_trr,multiorg
#
# abo_mat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6083301066692794
# Selected features abo_mat,diag,log_creat_trr
#
# urine_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6064919093717275
# Selected features diag,log_creat_trr,urine_inf_don
#
# gender
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6095868047374708
# Selected features diag,log_creat_trr,gender
#
# hematocrit_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5982381969193091
# Selected features diag,log_creat_trr,hematocrit_don
#
# tot_serum_album
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6090946308816401
# Selected features diag,log_creat_trr,tot_serum_album
#
# education
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073591562045598
# Selected features diag,log_creat_trr,education
#
# protein_urine
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6064883872304097
# Selected features protein_urine,diag,log_creat_trr
#
# skin_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073734391551484
# Selected features diag,skin_cancer_don,log_creat_trr
#
# hemo_pcw_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6071716233665125
# Selected features diag,log_creat_trr,hemo_pcw_tcr
#
# height ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6064998408779559
# Selected features diag,height ratio,log_creat_trr
#
# pulm_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6059519584222677
# Selected features diag,log_creat_trr,pulm_inf_don
#
# func_stat_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6110163091620978
# Selected features diag,log_creat_trr,func_stat_tcr
#
# log_hgt_cm_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6141393396430479
# Selected features diag,log_creat_trr,log_hgt_cm_calc
#
# vdrl_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6075107549251698
# Selected features vdrl_don,diag,log_creat_trr
#
# hcv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6075189923259854
# Selected features hcv_serostatus,diag,log_creat_trr
#
# hist_mi
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.607152413078563
# Selected features diag,hist_mi,log_creat_trr
#
# ebv_igg_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6063096467265656
# Selected features diag,log_creat_trr,ebv_igg_cad_don
#
# pvr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.605428255007435
# Selected features diag,pvr,log_creat_trr
#
# ebv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.606556039825307
# Selected features diag,log_creat_trr,ebv_serostatus
#
# log_newpra
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6094416163089602
# Selected features diag,log_creat_trr,log_newpra
#
# transfusions
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6197829531360713
# Selected features diag,transfusions,log_creat_trr
#
# ethcat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073154732157904
# Selected features diag,ethcat,log_creat_trr
#
# hbv_sur_antigen
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6072830611596008
# Selected features hbv_sur_antigen,diag,log_creat_trr
#
# clin_infect_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6052091596683343
# Selected features clin_infect_don,diag,log_creat_trr
#
# cod_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6141944715338623
# Selected features diag,log_creat_trr,cod_cad_don
#
# log_wgt_kg_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6114738254550326
# Selected features log_wgt_kg_calc,diag,log_creat_trr
#
# anyvent
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6107409466556726
# Selected features diag,anyvent,log_creat_trr
#
# log_ischtime
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6132796505314426
# Selected features diag,log_creat_trr,log_ischtime
#
# lv_eject
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.605103814427853
# Selected features lv_eject,diag,log_creat_trr
#
# malig
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6078917180349023
# Selected features diag,malig,log_creat_trr
#
# hist_hypertens_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6099274146895616
# Selected features diag,hist_hypertens_don,log_creat_trr
#
# diabetes_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6071921680329407
# Selected features diag,diabetes_don,log_creat_trr
#
# iabp_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6060010689147355
# Selected features diag,log_creat_trr,iabp_tcr
#
# weight ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6027178937607237
# Selected features diag,log_creat_trr,weight ratio
#
# hist_cocaine_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6062952388493736
# Selected features diag,log_creat_trr,hist_cocaine_don
#
# inotropes_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6054204258195502
# Selected features diag,inotropes_tcr,log_creat_trr
#
# hist_iv_drug_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073433404733481
# Selected features diag,hist_iv_drug_old_don,log_creat_trr
#
# log_sgot_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6073125294439059
# Selected features diag,log_sgot_don,log_creat_trr
#
# bmi_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6059781620387267
# Selected features diag,bmi_calc,log_creat_trr
#
# hbv_core
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6070765925094315
# Selected features hbv_core,diag,log_creat_trr
#
# cig_use
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.5969921102228933
# Selected features cig_use,diag,log_creat_trr
#
# ventilator_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6124358741325076
# Selected features diag,log_creat_trr,ventilator_tcr
#
# cmv_status
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6065804450711574
# Selected features diag,log_creat_trr,cmv_status
#
# intracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6072783765143599
# Selected features diag,log_creat_trr,intracranial_cancer_don
#
# log_distance
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6037285682757544
# Selected features diag,log_creat_trr,log_distance
#
# dial_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6124925260642822
# Selected features dial_after_list,diag,log_creat_trr
#
# abo_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6092493294544874
# Selected features abo_don,diag,log_creat_trr
#
# prior_card_surg_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6107873214286651
# Selected features diag,log_creat_trr,prior_card_surg_tcr
#
#
# ---------------------
# Selected feature: log_tbili
# ROC AUC 0.625628925038315
# All features: ['log_creat_trr', 'diag', 'log_tbili']
# Time elapsed: 0:08:46
# ---------------------
#
# iter 3 available 111
# log_tbili_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6253540674031701
# Selected features log_tbili_don,diag,log_creat_trr,log_tbili
#
# log_age
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6356710830802037
# Selected features diag,log_creat_trr,log_age,log_tbili
#
# impl_defibril
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6241106932733886
# Selected features impl_defibril,diag,log_creat_trr,log_tbili
#
# cancer_site_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6269318469000377
# Selected features diag,cancer_site_don,log_creat_trr,log_tbili
#
# prior_card_surg_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6272226624053748
# Selected features diag,log_creat_trr,prior_card_surg_trr,log_tbili
#
# coronary_angio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6308871129083935
# Selected features diag,log_creat_trr,coronary_angio,log_tbili
#
# tah ever
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6259053702352263
# Selected features tah ever,diag,log_creat_trr,log_tbili
#
# tattoos
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6253354141133514
# Selected features tattoos,diag,log_creat_trr,log_tbili
#
# biopsy_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6255705651219391
# Selected features biopsy_dgn,diag,log_creat_trr,log_tbili
#
# log_wgt_kg_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6258834652948604
# Selected features log_wgt_kg_don_calc,diag,log_creat_trr,log_tbili
#
# gender_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6284254790480086
# Selected features diag,log_creat_trr,gender_don,log_tbili
#
# cmv_igm
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6230431587894572
# Selected features cmv_igm,diag,log_creat_trr,log_tbili
#
# other_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6253711553039766
# Selected features diag,log_creat_trr,other_inf_don,log_tbili
#
# retransplant
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6272211506402174
# Selected features diag,log_creat_trr,retransplant,log_tbili
#
# hbv_sur_antigen_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6255833045803091
# Selected features diag,hbv_sur_antigen_don,log_creat_trr,log_tbili
#
# diab
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6240638331706809
# Selected features diag,log_creat_trr,diab,log_tbili
#
# hist_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6264760353232378
# ...
#
# hist_mi
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6535020157607919
# Selected features diag,transfusions,log_creat_trr,log_age_don,hist_mi,log_tbili,log_hgt_cm_calc
#
# ebv_igg_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6526697875041285
# Selected features diag,transfusions,log_creat_trr,log_age_don,ebv_igg_cad_don,log_tbili,log_hgt_cm_calc
#
# pvr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6513282519391492
# Selected features diag,transfusions,log_creat_trr,log_age_don,pvr,log_tbili,log_hgt_cm_calc
#
# ebv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6535934238008251
# Selected features ebv_serostatus,diag,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_newpra
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6550632960849021
# Selected features diag,transfusions,log_creat_trr,log_age_don,log_newpra,log_tbili,log_hgt_cm_calc
#
# ethcat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6549081226158081
# Selected features diag,transfusions,log_creat_trr,ethcat,log_age_don,log_tbili,log_hgt_cm_calc
#
# hbv_sur_antigen
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6536568361029986
# Selected features diag,transfusions,log_creat_trr,hbv_sur_antigen,log_age_don,log_tbili,log_hgt_cm_calc
#
# clin_infect_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6528261157815821
# Selected features diag,transfusions,log_creat_trr,log_age_don,clin_infect_don,log_tbili,log_hgt_cm_calc
#
# cod_cad_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6544996586977613
# Selected features diag,transfusions,log_creat_trr,cod_cad_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_wgt_kg_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6560015343230966
# Selected features log_wgt_kg_calc,diag,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# anyvent
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6533735843315694
# Selected features diag,anyvent,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_ischtime
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6569913324520391
# Selected features diag,transfusions,log_creat_trr,log_ischtime,log_age_don,log_tbili,log_hgt_cm_calc
#
# lv_eject
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6527328371387638
# Selected features diag,transfusions,log_creat_trr,lv_eject,log_age_don,log_tbili,log_hgt_cm_calc
#
# malig
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6540136770665643
# Selected features diag,transfusions,log_creat_trr,log_age_don,malig,log_tbili,log_hgt_cm_calc
#
# hist_hypertens_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6541905810657086
# Selected features diag,transfusions,log_creat_trr,log_age_don,hist_hypertens_don,log_tbili,log_hgt_cm_calc
#
# diabetes_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6540206928162948
# Selected features diag,transfusions,log_creat_trr,log_age_don,diabetes_don,log_tbili,log_hgt_cm_calc
#
# iabp_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6537114331497851
# Selected features diag,transfusions,log_creat_trr,log_age_don,iabp_tcr,log_tbili,log_hgt_cm_calc
#
# weight ratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6537893977470274
# Selected features diag,weight ratio,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# hist_cocaine_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6539641202369645
# Selected features diag,transfusions,log_creat_trr,log_age_don,hist_cocaine_don,log_tbili,log_hgt_cm_calc
#
# inotropes_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6536613958837852
# Selected features diag,inotropes_tcr,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# hist_iv_drug_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6539824315761554
# Selected features diag,hist_iv_drug_old_don,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_sgot_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6525687791470982
# Selected features diag,transfusions,log_creat_trr,log_age_don,log_sgot_don,log_tbili,log_hgt_cm_calc
#
# bmi_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6547444050702017
# Selected features diag,transfusions,log_creat_trr,log_age_don,bmi_calc,log_tbili,log_hgt_cm_calc
#
# hbv_core
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6536777140993457
# Selected features hbv_core,diag,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# cig_use
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6471848569048922
# Selected features cig_use,diag,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# ventilator_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6547191206570072
# Selected features diag,ventilator_tcr,transfusions,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# cmv_status
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6534636540990336
# Selected features diag,transfusions,log_creat_trr,cmv_status,log_age_don,log_tbili,log_hgt_cm_calc
#
# intracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6536509787313156
# Selected features diag,transfusions,log_creat_trr,intracranial_cancer_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_distance
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6527869029150347
# Selected features diag,transfusions,log_creat_trr,log_distance,log_age_don,log_tbili,log_hgt_cm_calc
#
# dial_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.655423533622661
# Selected features diag,transfusions,log_creat_trr,dial_after_list,log_age_don,log_tbili,log_hgt_cm_calc
#
# abo_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6542440907516485
# Selected features diag,transfusions,log_creat_trr,abo_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# prior_card_surg_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6542984592561323
# Selected features diag,transfusions,log_creat_trr,log_age_don,prior_card_surg_tcr,log_tbili,log_hgt_cm_calc
#
#
# ---------------------
# Selected feature: log_age
# ROC AUC 0.6591366667503121
# All features: ['log_creat_trr', 'diag', 'log_tbili', 'log_age_don', 'transfusions', 'log_hgt_cm_calc', 'log_age']
# Time elapsed: 0:09:15
# ---------------------
#
# iter 7 available 107
# log_tbili_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.657944454018359
# Selected features log_tbili_don,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# impl_defibril
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6587337730678408
# Selected features diag,transfusions,log_age,log_creat_trr,impl_defibril,log_age_don,log_tbili,log_hgt_cm_calc
#
# cancer_site_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6584151116061254
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,cancer_site_don,log_tbili,log_hgt_cm_calc
#
# prior_card_surg_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6582398070620704
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,prior_card_surg_trr,log_tbili,log_hgt_cm_calc
#
# coronary_angio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6588805947231179
# Selected features diag,transfusions,log_age,log_creat_trr,coronary_angio,log_age_don,log_tbili,log_hgt_cm_calc
#
# tah ever
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6585408059785591
# Selected features diag,transfusions,log_age,log_creat_trr,tah ever,log_age_don,log_tbili,log_hgt_cm_calc
#
# tattoos
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6582780043208852
# Selected features diag,transfusions,log_age,log_creat_trr,tattoos,log_age_don,log_tbili,log_hgt_cm_calc
#
# biopsy_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6583314165551468
# Selected features diag,transfusions,log_age,log_creat_trr,biopsy_dgn,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_wgt_kg_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.658058912835204
# Selected features diag,transfusions,log_age,log_creat_trr,log_wgt_kg_don_calc,log_age_don,log_tbili,log_hgt_cm_calc
#
# gender_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6576821248366287
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,gender_don,log_tbili,log_hgt_cm_calc
#
# cmv_igm
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6574311178510518
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,cmv_igm,log_tbili,log_hgt_cm_calc
#
# other_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6584441708051934
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,other_inf_don,log_tbili,log_hgt_cm_calc
#
# retransplant
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6589114052352317
# Selected features diag,retransplant,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# hbv_sur_antigen_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6587970179001493
# Selected features diag,hbv_sur_antigen_don,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# diab
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6580333464968771
# Selected features diag,transfusions,log_age,log_creat_trr,diab,log_age_don,log_tbili,log_hgt_cm_calc
#
# hist_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6587326603568772
# Selected features diag,transfusions,log_age,log_creat_trr,hist_cancer_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# prev_tx_any
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6593098801465078
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,prev_tx_any,log_tbili,log_hgt_cm_calc
#
# hist_cig_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6579776592227694
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,hist_cig_don,log_tbili,log_hgt_cm_calc
#
# lv_eject_meth
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6588990974465019
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,lv_eject_meth,log_tbili,log_hgt_cm_calc
#
# dial_prior_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6610395006007311
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,dial_prior_tx,log_tbili,log_hgt_cm_calc
#
# hemo_co_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6559564011743243
# Selected features diag,transfusions,log_age,log_creat_trr,hemo_co_tcr,log_age_don,log_tbili,log_hgt_cm_calc
#
# vessels_50sten
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6586045222938951
# Selected features vessels_50sten,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# hbv_core_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.658483674884536
# Selected features diag,hbv_core_don,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# hep_c_anti_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.658113445099904
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,hep_c_anti_don,log_tbili,log_hgt_cm_calc
#
# log_cmassratio
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6580857758850698
# Selected features diag,log_cmassratio,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_bun_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.657991639279988
# Selected features diag,transfusions,log_age,log_creat_trr,log_bun_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# life_sup_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6599087740563826
# Selected features diag,transfusions,log_age,log_creat_trr,life_sup_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# ecd_donor
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6586245706421727
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,ecd_donor,log_tbili,log_hgt_cm_calc
#
# cmv_igg
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6571285275044693
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,cmv_igg,log_tbili,log_hgt_cm_calc
#
# prior_card_surg_type_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6575540605611357
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,prior_card_surg_type_tcr,log_tbili,log_hgt_cm_calc
#
# prev_tx
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.659138697186253
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,prev_tx,log_tbili,log_hgt_cm_calc
#
# med_cond_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6594346420831954
# Selected features med_cond_trr,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# bmi_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.656088102319415
# Selected features diag,bmi_don_calc,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_creat_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6578588204314537
# Selected features diag,transfusions,log_age,log_creat_trr,log_creat_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_sgpt_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6583817266745733
# Selected features diag,transfusions,log_age,log_creat_trr,log_sgpt_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# vasodil_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6584680750441702
# Selected features diag,transfusions,log_age,log_creat_trr,vasodil_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# hemo_pa_mn_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6580616318595359
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,hemo_pa_mn_tcr,log_tbili,log_hgt_cm_calc
#
# hiv_serostatus
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6584989689122376
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,hiv_serostatus,log_tbili,log_hgt_cm_calc
#
# congenital
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6589247169101736
# Selected features congenital,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# contin_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.658698066880551
# Selected features diag,transfusions,log_age,log_creat_trr,contin_oth_drug_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# hist_oth_drug_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6589544755194923
# Selected features hist_oth_drug_don,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# sexmatch
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6573771755492553
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,sexmatch,log_tbili,log_hgt_cm_calc
#
# vent_support_after_list
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6595158446575545
# Selected features vent_support_after_list,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# ecmo_trr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6619606153796366
# Selected features ecmo_trr,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# hemo_sys_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6585443194191926
# Selected features diag,transfusions,log_age,log_creat_trr,hemo_sys_tcr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_hgt_cm_don_calc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6580111803324343
# Selected features diag,transfusions,log_age,log_creat_trr,log_hgt_cm_don_calc,log_age_don,log_tbili,log_hgt_cm_calc
#
# hemo_pa_dia_tcr
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6572490807966967
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,hemo_pa_dia_tcr,log_tbili,log_hgt_cm_calc
#
# abo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6582858118751632
# Selected features diag,abo,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# blood_inf_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6583503097230915
# Selected features diag,transfusions,log_age,log_creat_trr,blood_inf_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# hist_alcohol_old_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6586961660230783
# Selected features hist_alcohol_old_don,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# anyecmo
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6609491818063137
# Selected features anyecmo,diag,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# donor insulin
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6584464979640957
# Selected features diag,donor insulin,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# thoracic_dgn
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6577648287215249
# Selected features diag,thoracic_dgn,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# cereb_vasc
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.658709631816045
# Selected features diag,transfusions,log_age,log_creat_trr,cereb_vasc,log_age_don,log_tbili,log_hgt_cm_calc
#
# extracranial_cancer_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6583601067975411
# Selected features diag,transfusions,log_age,log_creat_trr,extracranial_cancer_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# cmv_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6582162211909226
# Selected features diag,transfusions,log_age,log_creat_trr,cmv_don,log_age_don,log_tbili,log_hgt_cm_calc
#
# alcohol_heavy_don
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.657965999797476
# Selected features diag,alcohol_heavy_don,transfusions,log_age,log_creat_trr,log_age_don,log_tbili,log_hgt_cm_calc
#
# log_most_rcnt_creat
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ROC AUC 0.6604679906023814
# Selected features diag,transfusions,log_age,log_creat_trr,log_age_don,log_most_rcnt_creat,log_tbili,log_hgt_cm_calc
#
# death_mech_don
# .
# .
# .

# %%
rocs = [ try_except(lambda: get_max_roc_auc_from_results(iteration), {Exception: lambda: None}) for _, iteration in final_results['xgboost'].items()]

# %%
rocs

# %%
final_used_features
